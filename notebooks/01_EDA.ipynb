# %%
# !git clone https://github.com/aymenichqa/flipkart_sentiments_pfa.git
# Out:
# Cloning into 'flipkart_sentiments_pfa'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 36 (delta 11), reused 6 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (36/36), 12.50 KiB | 2.08 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
# %cd flipkart_sentiments_pfa
# Out:
# /content/flipkart_sentiments_pfa

# %%
USER_NAME = "aymenichqa"
TOKEN = "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"
remote_url = f"https://{USER_NAME}:{TOKEN}@github.com/{USER_NAME}/flipkart_sentiments_pfa.git"
# !git remote set-url origin {remote_url}

# %%
# !git push origin --delete develop
# !git push origin --delete feature/eda
# Out:
# To https://github.com/aymenichqa/flipkart_sentiments_pfa.git
#  - [deleted]         develop
# To https://github.com/aymenichqa/flipkart_sentiments_pfa.git
#  - [deleted]         feature/eda

# %%
# !git checkout -b develop
# !git push -u origin develop
# Out:
# Switched to a new branch 'develop'
# Total 0 (delta 0), reused 0 (delta 0), pack-reused 0
# remote:
# remote: Create a pull request for 'develop' on GitHub by visiting:
# remote:      https://github.com/aymenichqa/flipkart_sentiments_pfa/pull/new/develop
# remote:
# To https://github.com/aymenichqa/flipkart_sentiments_pfa.git
#  * [new branch]      develop -> develop
# Branch 'develop' set up to track remote branch 'develop' from 'origin'.

# %%
# !git checkout -b feature/eda
# !git push -u origin feature/eda
# Out:
# Switched to a new branch 'feature/eda'
# Total 0 (delta 0), reused 0 (delta 0), pack-reused 0
# remote:
# remote: Create a pull request for 'feature/eda' on GitHub by visiting:
# remote:      https://github.com/aymenichqa/flipkart_sentiments_pfa/pull/new/feature/eda
# remote:
# To https://github.com/aymenichqa/flipkart_sentiments_pfa.git
#  * [new branch]      feature/eda -> feature/eda
# Branch 'feature/eda' set up to track remote branch 'feature/eda' from 'origin'.

# %%
# !mv /01_EDA.ipynb /content/flipkart_sentiments_pfa/notebooks/01_EDA.ipynb
# Out:
# mv: cannot stat '/01_EDA.ipynb': No such file or directory

# %%
# !ls /content/
# Out:
# flipkart_sentiments_pfa  sample_data

# %%
# !ls -R /content/flipkart_sentiments_pfa
# Out:
# /content/flipkart_sentiments_pfa:
# data  LICENSE  models  notebooks  README.md  requirements.txt  src
#
# /content/flipkart_sentiments_pfa/data:
# README.md
#
# /content/flipkart_sentiments_pfa/models:
#
# /content/flipkart_sentiments_pfa/notebooks:
# 01_EDA.ipynb
#
# /content/flipkart_sentiments_pfa/src:
# evaluate.py  models.py	preprocessing.py
